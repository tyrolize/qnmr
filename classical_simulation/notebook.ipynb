# %%
from NMRSpectrum import NMRSpectrum

# %%
import matplotlib.pyplot as plt

plt.plot(NMRSpectrum(3))
plt.show()
# Out:
# /home/tyro/anaconda3/envs/qaoaEnv/lib/python3.8/site-packages/scipy/sparse/linalg/eigen/arpack/arpack.py:1266: RuntimeWarning: k >= N - 1 for N * N square matrix. Attempting to use scipy.linalg.eig instead.
#   warnings.warn("k >= N - 1 for N * N square matrix. "
# /home/tyro/anaconda3/envs/qaoaEnv/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
